# %% [markdown]
# <a href="https://colab.research.google.com/github/vaishali28h-crypto/NLP-LAB/blob/main/exp4_nlp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from nltk.tokenize import word_tokenize,sent_tokenize

# %%
input ="Hi i am vaishali. How  are you"
output1 = word_tokenize(input)
print(output1)
# Out:
# ['Hi', 'i', 'am', 'vaishali', '.', 'How', 'are', 'you']

# %%
output2 = sent_tokenize(input)
print(output2)
# Out:
# ['Hi i am vaishali.', 'How  are you']

# %%
# !pip install -U spacy

# %%
# !python -m download en_core_web_sm
# Out:
# /usr/bin/python3: No module named download

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
input = " this is the second session "
doc = nlp(input)

# %%
for token in doc:
  print(token)
# Out:
#
# this
# is
# the
# second
# session

# %%
for sent in doc. sents:
  print(sent)
# Out:
#  this is the second session
